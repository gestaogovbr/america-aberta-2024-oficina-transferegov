# %% [markdown]
# ## Oficina de dados abertos do Transferegov
# O foco da oficina será na parte das emendas parlamentares chamadas "emendas Pix" que é operacionaliza pelo Transferegov, no módulo de Transferências Especiais. Os dados estão disponibilizados por meio de API de dados abertos.
#
# #Endereço da API: https://docs.api.transferegov.gestao.gov.br/transferenciasespeciais/#/plano_acao_especial/get_plano_acao_especial
#
# ## Plano de ação especial
# Vamos carregar em uma única tabela todos os dados de Plano de Ação Especial.
#
# ## Baixar os dados

# %%
import pandas as pd
import requests
from tqdm.notebook import tqdm

# %%
LIMIT = 1000
ANO = 2024
URL = "https://api.transferegov.gestao.gov.br/transferenciasespeciais/plano_acao_especial"

# %%
content = requests.get(
    URL,
    params={
        "ano_emenda_parlamentar_plano_acao": f"eq.{ANO}",
        "limit": 10,
    },
    headers={
        "Prefer": "count=exact",
    }
)

# %%
content.headers
record_count = int(content.headers["Content-Range"].split("/")[-1])
record_count
# Out:
# 10934

# %%
data = content.json()

# %%
df = pd.DataFrame(columns=data[0].keys())

# %%
df.columns
# Out:
# Index(['id_plano_acao', 'codigo_plano_acao', 'ano_plano_acao',
#        'modalidade_plano_acao', 'situacao_plano_acao',
#        'cnpj_beneficiario_plano_acao', 'nome_beneficiario_plano_acao',
#        'uf_beneficiario_plano_acao', 'codigo_banco_plano_acao',
#        'codigo_situacao_dado_bancario_plano_acao', 'nome_banco_plano_acao',
#        'numero_agencia_plano_acao', 'dv_agencia_plano_acao',
#        'numero_conta_plano_acao', 'dv_conta_plano_acao',
#        'nome_parlamentar_emenda_plano_acao',
#        'ano_emenda_parlamentar_plano_acao',
#        'codigo_parlamentar_emenda_plano_acao',
#        'sequencial_emenda_parlamentar_plano_acao',
#        'numero_emenda_parlamentar_plano_acao',
#        'codigo_emenda_parlamentar_formatado_plano_acao',
#        'codigo_descricao_areas_politicas_publicas_plano_acao',
#        'descricao_programacao_orcamentaria_plano_acao',
#        'motivo_impedimento_plano_acao', 'valor_custeio_plano_acao',
#        'valor_investimento_plano_acao', 'id_programa'],
#       dtype='object')

# %%
pages = []

# %%
pages = []
for offset in range(0, record_count, LIMIT):
    content = requests.get(
        URL,
        params={
            "ano_emenda_parlamentar_plano_acao": f"eq.{ANO}",
            "limit": LIMIT,
            "offset": offset,
        },
    )
    pages.extend(content.json())

df = pd.DataFrame(pages)
df
# Out:
#        id_plano_acao codigo_plano_acao  ano_plano_acao modalidade_plano_acao  \
# 0              69182   09032024-069182            2024              Especial
# 1              64478   09032024-064478            2024              Especial
# 2              64487   09032024-064487            2024              Especial
# 3              72493   09032024-072493            2024              Especial
# 4              73453   09032024-073453            2024              Especial
# ...              ...               ...             ...                   ...
# 10929          74317   09032024-074317            2024              Especial
# 10930          69119   09032024-069119            2024              Especial
# 10931          73476   09032024-073476            2024              Especial
# 10932          72488   09032024-072488            2024              Especial
# 10933          69007   09032024-069007            2024              Especial
#
#       situacao_plano_acao cnpj_beneficiario_plano_acao  \
# 0                  CIENTE               95990131000170
# 1                  CIENTE               41522186000126
# 2                  CIENTE               01612590000176
# 3                  CIENTE               18114264000131
# 4                  CIENTE               18114264000131
# ...                   ...                          ...
# 10929              CIENTE               75368928000122
# 10930              CIENTE               14196042000154
# 10931              CIENTE               18094870000132
# 10932              CIENTE               46362927000172
# 10933              CIENTE               02295772000123
#
#                 nome_beneficiario_plano_acao uf_beneficiario_plano_acao  \
# 0                MUNICIPIO DE NOVA ITABERABA                         SC
# 1      MUNICIPIO DE PASSAGEM FRANCA DO PIAUI                         PI
# 2                MUNICIPIO DE MILTON BRANDAO                         PI
# 3                  MUNICIPIO DE ESPERA FELIZ                         MG
# 4                  MUNICIPIO DE ESPERA FELIZ                         MG
# ...                                      ...                        ...
# 10929                   MUNICIPIO DE MAMBORE                         PR
# 10930                              TEOLÂNDIA                         BA
# 10931      MUNICIPIO DE SENHORA DOS REMEDIOS                         MG
# 10932                    MUNICIPIO DE BROTAS                         SP
# 10933                     MUNICIPIO DE GOIAS                         GO
#
#       codigo_banco_plano_acao  codigo_situacao_dado_bancario_plano_acao  ...  \
# 0                         104                                       4.0  ...
# 1                         001                                       4.0  ...
# 2                         104                                       4.0  ...
# 3                         104                                       4.0  ...
# 4                         104                                       4.0  ...
# ...                       ...                                       ...  ...
# 10929                     104                                       4.0  ...
# 10930                     104                                       4.0  ...
# 10931                     001                                       4.0  ...
# 10932                     104                                       4.0  ...
# 10933                     104                                       4.0  ...
#
#       codigo_parlamentar_emenda_plano_acao  \
# 0                                     2855
# 1                                     4496
# 2                                     4496
# 3                                     3731
# 4                                     4057
# ...                                    ...
# 10929                                 4313
# 10930                                 3906
# 10931                                 4057
# 10932                                 3730
# 10933                                 1960
#
#        sequencial_emenda_parlamentar_plano_acao  \
# 0                                            22
# 1                                             1
# 2                                             1
# 3                                             9
# 4                                             3
# ...                                         ...
# 10929                                         1
# 10930                                         5
# 10931                                         3
# 10932                                        11
# 10933                                        17
#
#       numero_emenda_parlamentar_plano_acao  \
# 0                             202428550022
# 1                             202444960001
# 2                             202444960001
# 3                             202437310009
# 4                             202440570003
# ...                                    ...
# 10929                         202443130001
# 10930                         202439060005
# 10931                         202440570003
# 10932                         202437300011
# 10933                         202419600017
#
#        codigo_emenda_parlamentar_formatado_plano_acao  \
# 0                            202428550022-Pedro Uczai
# 1                           202444960001-Jussara Lima
# 2                           202444960001-Jussara Lima
# 3                         202437310009-Misael Varella
# 4                            202440570003-Pinheirinho
# ...                                               ...
# 10929                         202443130001-Beto Preto
# 10930                       202439060005-Alex Santana
# 10931                        202440570003-Pinheirinho
# 10932                    202437300011-Miguel Lombardi
# 10933                       202419600017-Rubens Otoni
#
#       codigo_descricao_areas_politicas_publicas_plano_acao  \
# 0               15-Urbanismo / 451-Infraestrutura Urbana
# 1      13-Cultura / 391-Patrimônio Histórico, Artísti...
# 2      6-Segurança Pública / 181-Policiamento , 6-Seg...
# 3      10-Saúde / 301-Atenção Básica , 10-Saúde / 302...
# 4      10-Saúde / 301-Atenção Básica , 10-Saúde / 302...
# ...                                                  ...
# 10929  15-Urbanismo / 451-Infraestrutura Urbana , 20-...
# 10930  8-Assistência Social / 244-Assistência Comunit...
# 10931  6-Segurança Pública / 181-Policiamento , 6-Seg...
# 10932           15-Urbanismo / 451-Infraestrutura Urbana
# 10933  14-Direitos da Cidadania / 422-Direitos Indivi...
#
#       descricao_programacao_orcamentaria_plano_acao  \
# 0                                              None
# 1                                              None
# 2                                              None
# 3                                              None
# 4                                              None
# ...                                             ...
# 10929                                          None
# 10930                                          None
# 10931                                          None
# 10932                                          None
# 10933                                          None
#
#       motivo_impedimento_plano_acao valor_custeio_plano_acao  \
# 0                              None                      0.0
# 1                              None                      0.0
# 2                              None                      0.0
# 3                              None                      0.0
# 4                              None                      0.0
# ...                             ...                      ...
# 10929                          None                      0.0
# 10930                          None                1530737.0
# 10931                          None                      0.0
# 10932                          None                      0.0
# 10933                          None                      0.0
#
#        valor_investimento_plano_acao id_programa
# 0                           400000.0          21
# 1                           250000.0          21
# 2                           250000.0          21
# 3                           500000.0          21
# 4                          2000000.0          21
# ...                              ...         ...
# 10929                       670000.0          21
# 10930                      2469263.0          21
# 10931                       500000.0          21
# 10932                       300000.0          21
# 10933                       400000.0          21
#
# [10934 rows x 27 columns]

# %% [markdown]
# ## Análise

# %%
df["nome_parlamentar_emenda_plano_acao"].value_counts()
# Out:
# nome_parlamentar_emenda_plano_acao
# Ivete da Silveira     178
# Jorge Seif            167
# Ciro Nogueira         103
# Luis Carlos Heinze     92
# Fred Costa             91
#                      ...
# Célia Xakriabá          1
# Carlos Jordy            1
# Geraldo Resende         1
# Marcos Soares           1
# Daniella Ribeiro        1
# Name: count, Length: 530, dtype: int64

# %%
df["valor_emenda"] = df["valor_custeio_plano_acao"] + df["valor_investimento_plano_acao"]

# %%
total_emendas_por_parlamentar = df.groupby("nome_parlamentar_emenda_plano_acao").sum()["valor_emenda"]
total_emendas_por_parlamentar
# Out:
# nome_parlamentar_emenda_plano_acao
# Abilio Brunini      8485793.0
# Acácio Favacho     16732792.0
# Adail Filho        18434456.0
# Adilson Barroso    15515785.0
# Adolfo Viana       15650000.0
#                       ...
# Zé Silva           13835792.0
# Zé Trovão          14935792.0
# Zé Vitor           17671585.0
# Átila Lins         15121585.0
# Átila Lira         17585585.0
# Name: valor_emenda, Length: 530, dtype: float64

# %%
total_emendas_por_parlamentar.sort_values(ascending=False)[:20]
# Out:
# nome_parlamentar_emenda_plano_acao
# Jussara Lima                 34817425.0
# Marcos Rogério               34817425.0
# Jayme Campos                 34817425.0
# Davi Alcolumbre              34815000.0
# Otto Alencar                 34634850.0
# Ciro Nogueira                34634850.0
# Giordano                     34500000.0
# Eliziane Gama                34317425.0
# Fernando Farias              34317425.0
# Angelo Coronel               34134850.0
# Marcelo Castro               33517425.0
# Randolfe Rodrigues           33517425.0
# Mecias de Jesus              33500000.0
# Carlos Fávaro                33332850.0
# Dr. Hiran                    33300000.0
# Styvenson Valentim           32774850.0
# Zenaide Maia                 32360000.0
# Luis Carlos Heinze           32017350.0
# Professora Dorinha Seabra    31417420.0
# Nelsinho Trad                30816850.0
# Name: valor_emenda, dtype: float64

# %%
import matplotlib.pyplot as plt

# Ordenar os dados e selecionar os 20 maiores valores
top_20_emendas = total_emendas_por_parlamentar.sort_values(ascending=False)[:20]

# Criar o gráfico de barras horizontais
plt.figure(figsize=(12, 6))
top_20_emendas.plot(kind='barh', color='skyblue', edgecolor='black')

# Adicionar título e rótulos
plt.title('Top 20 Parlamentares por Valor de Emendas', fontsize=16)
plt.xlabel('Valor Total das Emendas', fontsize=12)
plt.ylabel('Parlamentares', fontsize=12)
plt.grid(axis='x', linestyle='--', alpha=0.7)

# Ajustar layout e exibir
plt.tight_layout()
plt.show()

# %%
# URL da API da Câmara para obter partidos
url = "https://dadosabertos.camara.leg.br/api/v2/deputados"

# Requisição dos dados
response = requests.get(url, params={})
data = response.json()["dados"]

# Convertendo para DataFrame
#df_deputados = pd.DataFrame(data)[["id", "nome", "siglaPartido", "siglaUf"]]
df_deputados = pd.DataFrame(data)
df_deputados = df_deputados.rename(columns={"siglaPartido":"partido"})
# Exibindo os primeiros registros
print(df_deputados.head())
# Out:
#        id                                                uri             nome  \
# 0  220593  https://dadosabertos.camara.leg.br/api/v2/depu...   Abilio Brunini
# 1  204379  https://dadosabertos.camara.leg.br/api/v2/depu...   Acácio Favacho
# 2  220714  https://dadosabertos.camara.leg.br/api/v2/depu...      Adail Filho
# 3  221328  https://dadosabertos.camara.leg.br/api/v2/depu...  Adilson Barroso
# 4  204560  https://dadosabertos.camara.leg.br/api/v2/depu...     Adolfo Viana
#
#         partido                                         uriPartido siglaUf  \
# 0            PL  https://dadosabertos.camara.leg.br/api/v2/part...      MT
# 1           MDB  https://dadosabertos.camara.leg.br/api/v2/part...      AP
# 2  REPUBLICANOS  https://dadosabertos.camara.leg.br/api/v2/part...      AM
# 3            PL  https://dadosabertos.camara.leg.br/api/v2/part...      SP
# 4          PSDB  https://dadosabertos.camara.leg.br/api/v2/part...      BA
#
#    idLegislatura                                            urlFoto  \
# 0             57  https://www.camara.leg.br/internet/deputado/ba...
# 1             57  https://www.camara.leg.br/internet/deputado/ba...
# 2             57  https://www.camara.leg.br/internet/deputado/ba...
# 3             57  https://www.camara.leg.br/internet/deputado/ba...
# 4             57  https://www.camara.leg.br/internet/deputado/ba...
#
#                               email
# 0   dep.abiliobrunini@camara.leg.br
# 1   dep.acaciofavacho@camara.leg.br
# 2      dep.adailfilho@camara.leg.br
# 3  dep.adilsonbarroso@camara.leg.br
# 4     dep.adolfoviana@camara.leg.br

# %%
df_deputados.columns
# Out:
# Index(['id', 'uri', 'nome', 'partido', 'uriPartido', 'siglaUf',
#        'idLegislatura', 'urlFoto', 'email'],
#       dtype='object')

# %%
df[df['nome_parlamentar_emenda_plano_acao']=='Abilio Brunini']
# Out:
#        id_plano_acao codigo_plano_acao  ano_plano_acao modalidade_plano_acao  \
# 676            68061   09032024-068061            2024              Especial
# 681            68070   09032024-068070            2024              Especial
# 686            68067   09032024-068067            2024              Especial
# 3852           68071   09032024-068071            2024              Especial
# 5574           68064   09032024-068064            2024              Especial
# 6100           68066   09032024-068066            2024              Especial
# 6104           68063   09032024-068063            2024              Especial
# 7590           68069   09032024-068069            2024              Especial
# 7681           68065   09032024-068065            2024              Especial
# 8802           68062   09032024-068062            2024              Especial
# 10314          68068   09032024-068068            2024              Especial
#
#       situacao_plano_acao cnpj_beneficiario_plano_acao  \
# 676                CIENTE               01617905000178
# 681                CIENTE               24772162000106
# 686                CIENTE               03788239000166
# 3852               CIENTE               15023989000126
# 5574               CIENTE               15023906000107
# 6100               CIENTE               03507415000144
# 6104               CIENTE               37464948000108
# 7590               CIENTE               24772246000140
# 7681               CIENTE               03533064000146
# 8802               CIENTE               03507548000110
# 10314              CIENTE               15024003000132
#
#          nome_beneficiario_plano_acao uf_beneficiario_plano_acao  \
# 676             MUNICIPIO DE CARLINDA                         MT
# 681                        NOVA MUTUM                         MT
# 686     MUNICIPIO DE TANGARA DA SERRA                         MT
# 3852                 PONTES E LACERDA                         MT
# 5574       MUNICIPIO DE ALTA FLORESTA                         MT
# 6100            ESTADO DE MATO GROSSO                         MT
# 6104   MUNICIPIO DE SAO PEDRO DA CIPA                         MT
# 7590               LUCAS DO RIO VERDE                         MT
# 7681              MUNICIPIO DE CUIABA                         MT
# 8802       MUNICIPIO DE VARZEA GRANDE                         MT
# 10314              MUNICIPIO DE SINOP                         MT
#
#       codigo_banco_plano_acao  codigo_situacao_dado_bancario_plano_acao  ...  \
# 676                       001                                       4.0  ...
# 681                       104                                       4.0  ...
# 686                       104                                       4.0  ...
# 3852                      104                                       4.0  ...
# 5574                      001                                       4.0  ...
# 6100                      001                                       4.0  ...
# 6104                      104                                       4.0  ...
# 7590                      001                                       4.0  ...
# 7681                      104                                       4.0  ...
# 8802                      104                                       4.0  ...
# 10314                     001                                       4.0  ...
#
#       sequencial_emenda_parlamentar_plano_acao  \
# 676                                          6
# 681                                          6
# 686                                          6
# 3852                                         6
# 5574                                         6
# 6100                                         6
# 6104                                         6
# 7590                                         6
# 7681                                         6
# 8802                                         6
# 10314                                        6
#
#        numero_emenda_parlamentar_plano_acao  \
# 676                            202442900006
# 681                            202442900006
# 686                            202442900006
# 3852                           202442900006
# 5574                           202442900006
# 6100                           202442900006
# 6104                           202442900006
# 7590                           202442900006
# 7681                           202442900006
# 8802                           202442900006
# 10314                          202442900006
#
#       codigo_emenda_parlamentar_formatado_plano_acao  \
# 676                      202442900006-Abilio Brunini
# 681                      202442900006-Abilio Brunini
# 686                      202442900006-Abilio Brunini
# 3852                     202442900006-Abilio Brunini
# 5574                     202442900006-Abilio Brunini
# 6100                     202442900006-Abilio Brunini
# 6104                     202442900006-Abilio Brunini
# 7590                     202442900006-Abilio Brunini
# 7681                     202442900006-Abilio Brunini
# 8802                     202442900006-Abilio Brunini
# 10314                    202442900006-Abilio Brunini
#
#        codigo_descricao_areas_politicas_publicas_plano_acao  \
# 676                        10-Saúde / 301-Atenção Básica
# 681    10-Saúde / 301-Atenção Básica , 10-Saúde / 302...
# 686                        10-Saúde / 301-Atenção Básica
# 3852   27-Desporto e Lazer / 811-Desporto de Rendimen...
# 5574   8-Assistência Social / 242-Assistência ao Port...
# 6100   6-Segurança Pública / 181-Policiamento , 6-Seg...
# 6104   22-Indústria / 661-Promoção Industrial , 22-In...
# 7590                       10-Saúde / 301-Atenção Básica
# 7681   6-Segurança Pública / 181-Policiamento , 6-Seg...
# 8802   15-Urbanismo / 451-Infraestrutura Urbana , 15-...
# 10314  10-Saúde / 301-Atenção Básica , 10-Saúde / 302...
#
#       descricao_programacao_orcamentaria_plano_acao  \
# 676                                            None
# 681                                            None
# 686                                            None
# 3852                                           None
# 5574                                           None
# 6100                                           None
# 6104                                           None
# 7590                                           None
# 7681                                           None
# 8802                                           None
# 10314                                          None
#
#       motivo_impedimento_plano_acao valor_custeio_plano_acao  \
# 676                            None                      0.0
# 681                            None                 750000.0
# 686                            None                      0.0
# 3852                           None                      0.0
# 5574                           None                      0.0
# 6100                           None                1735793.0
# 6104                           None                      0.0
# 7590                           None                      0.0
# 7681                           None                      0.0
# 8802                           None                      0.0
# 10314                          None                      0.0
#
#       valor_investimento_plano_acao  id_programa valor_emenda
# 676                        150000.0           21     150000.0
# 681                             0.0           21     750000.0
# 686                        200000.0           21     200000.0
# 3852                       500000.0           21     500000.0
# 5574                      1350000.0           21    1350000.0
# 6100                            0.0           21    1735793.0
# 6104                       300000.0           21     300000.0
# 7590                       300000.0           21     300000.0
# 7681                      1977100.0           21    1977100.0
# 8802                       672900.0           21     672900.0
# 10314                      550000.0           21     550000.0
#
# [11 rows x 28 columns]

# %%
df.columns
# Out:
# Index(['id_plano_acao', 'codigo_plano_acao', 'ano_plano_acao',
#        'modalidade_plano_acao', 'situacao_plano_acao',
#        'cnpj_beneficiario_plano_acao', 'nome_beneficiario_plano_acao',
#        'uf_beneficiario_plano_acao', 'codigo_banco_plano_acao',
#        'codigo_situacao_dado_bancario_plano_acao', 'nome_banco_plano_acao',
#        'numero_agencia_plano_acao', 'dv_agencia_plano_acao',
#        'numero_conta_plano_acao', 'dv_conta_plano_acao',
#        'nome_parlamentar_emenda_plano_acao',
#        'ano_emenda_parlamentar_plano_acao',
#        'codigo_parlamentar_emenda_plano_acao',
#        'sequencial_emenda_parlamentar_plano_acao',
#        'numero_emenda_parlamentar_plano_acao',
#        'codigo_emenda_parlamentar_formatado_plano_acao',
#        'codigo_descricao_areas_politicas_publicas_plano_acao',
#        'descricao_programacao_orcamentaria_plano_acao',
#        'motivo_impedimento_plano_acao', 'valor_custeio_plano_acao',
#        'valor_investimento_plano_acao', 'id_programa', 'valor_emenda'],
#       dtype='object')

# %%
df.nome_parlamentar_emenda_plano_acao.unique()
# Out:
# array(['Pedro Uczai', 'Jussara Lima', 'Misael Varella', 'Pinheirinho',
#        'Pedro Westphalen', 'Amaro Neto', 'Efraim Filho',
#        'Arthur Oliveira Maia', 'Helder Salomão', 'Jeferson Rodrigues',
#        'Marcos do Val', 'Samuel Viana', 'Jorge Goetten',
#        'Pompeo de Mattos', 'Felipe Carreras', 'Luiz Fernando Faria',
#        'Styvenson Valentim', 'Eliziane Gama', 'Carlos Chiodini',
#        'Randolfe Rodrigues', 'Marcon', 'Marcelo Castro', 'Welter',
#        'Rosângela Reis', 'Mecias de Jesus', 'Romero Rodrigues',
#        'Olival Marques', 'Giacobo', 'Beto Richa', 'André Ferreira',
#        'Vermelho', 'Alencar Santana', 'Zé Neto', 'Daniel Almeida',
#        'Sargento Fahur', 'Arnaldo Jardim', 'Jader Barbalho',
#        'Alessandro Vieira', 'Carlos Viana', 'Jilmar Tatto', 'Júlio Cesar',
#        'Beto Faro', 'Eduardo Gomes', 'Rodrigo Cunha',
#        'Félix Mendonça Júnior', 'Jayme Campos', 'Alan Rick',
#        'Delegado Paulo Bilynskyj', 'Rafael Brito', 'Jaques Wagner',
#        'Cleber Verde', 'Sergio Moro', 'Gustavo Gayer', 'Zezinho Barbary',
#        'Ana Paula Lobato', 'Eli Borges', 'Felipe Francischini',
#        'Delegado Éder Mauro', 'Eduardo Bismarck', 'Laércio Oliveira',
#        'Yandra Moura', 'Gilberto Nascimento', 'Dimas Fabiano',
#        'Sidney Leite', 'Waldemar Oliveira', 'Fausto Santos Jr.',
#        'Coronel Ulysses', 'Castro Neto', 'Bohn Gass',
#        'Alexandre Lindenmeyer', 'Josenildo', 'Padovani',
#        'Julio Arcoverde', 'Paulo Marinho JR', 'Pastor Gil',
#        'Junior Lourenço', 'Silvio Antonio', 'Célio Studart',
#        'Carlos Henrique Gaguim', 'Jefferson Campos', 'Duarte Jr.',
#        'Jorge Seif', 'Ciro Nogueira', 'Júnior Mano', 'Paulo Litro',
#        'Capitão Augusto', 'Thiago de Joaldo', 'Cristiane Lopes',
#        'Zé Vitor', 'Jorge Kajuru', 'Eduardo Velloso', 'Maurício Carvalho',
#        'Átila Lira', 'Gutemberg Reis', 'Bruno Farias', 'Hamilton Mourão',
#        'Marcos Pereira', 'Dr. Benjamim', 'Delegada Katarina',
#        'Mário Negromonte Jr.', 'Ricardo Ayres',
#        'Astronauta Marcos Pontes', 'Adriano do Baldy', 'Flávia Morais',
#        'Lucio Mosquini', 'Damião Feliciano', 'Paulinho Freire',
#        'Delegado Palumbo', 'Diego Coronel', 'Jorge Solla',
#        'Humberto Costa', 'Icaro de Valmir', 'Danrlei de Deus Hinterholz',
#        'Elmar Nascimento', 'Luis Tibé', 'Paulo Azi', 'Amanda Gentil',
#        'Lázaro Botelho', 'Jonas Donizette', 'Heitor Schuch',
#        'Adolfo Viana', 'Maria Arraes', 'Gustinho Ribeiro',
#        'Fernando Dueire', 'Murilo Galdino', 'Lucas Redecker',
#        'Raimundo Santos', 'Márcio Honaiser', 'Delegado Fabio Costa',
#        'José Rocha', 'Euclydes Pettersen', 'Rubens Pereira Júnior',
#        'Renilce Nicodemos', 'Pastor Eurico', 'Flávio Arns',
#        'Carlos Gomes', 'Evair Vieira De Melo', 'Dr. Frederico',
#        'Rodrigo Gambale', 'Danilo Forte', 'Sergio Souza', 'Fausto Pinato',
#        'Fred Costa', 'Waldenor Pereira', 'Mendonça Filho',
#        'Rodrigo Valadares', 'Luciano Bivar', 'Keniston Braga',
#        'Dorinaldo Malafaia', 'Any Ortiz', 'Geraldo Mendes',
#        'Gabriel Nunes', 'Bibo Nunes', 'Fabio Reis', 'Alice Portugal',
#        'Igor Timo', 'Paulo Guedes', 'Coronel Assis', 'Lebrão', 'Zucco',
#        'Thiago Flores', 'Glaustin da Fokus', 'Carmen Zanotto',
#        'Carlos Veras', 'Paulo Magalhães', 'Marangoni', 'Vitor Lippi',
#        'Luis Carlos Heinze', 'Mário Heringer', 'Carlos Zarattini',
#        'João Daniel', 'Mauricio do Vôlei', 'Otto Alencar Filho',
#        'Rui Falcão', 'Ossesio Silva', 'João Maia', 'Junio Amaral',
#        'Lincoln Portela', 'Jack Rocha', 'Luciano Amaral', 'Eros Biondini',
#        'Vanderlan Cardoso', 'Antonio Andrade', 'Zé Silva',
#        'Rogéria Santos', 'Veneziano Vital do Rêgo', 'Florentino Neto',
#        'Mario Frias', 'Antonio Carlos Rodrigues', 'João Carlos Bacelar',
#        'Weverton', 'Claudio Cajado', 'Newton Cardoso Jr', 'General Girão',
#        'Ismael Alexandrino', 'Henderson Pinto', 'Alfredinho',
#        'Da Vitoria', 'Ana Pimentel', 'Renan Calheiros', 'Daniel Agrobom',
#        'Defensor Stélio Dener', 'Airton Faleiro', 'Luiz Gastão',
#        'Pedro Campos', 'Lídice da Mata', 'Robério Monteiro',
#        'Arlindo Chinaglia', 'Julia Zanatta', 'José Guimarães',
#        'Ruy Carneiro', 'Aliel Machado', 'Abilio Brunini',
#        'André Figueiredo', 'Luiz Nishimori', 'Emidinho Madeira',
#        'Fernando Monteiro', 'Delegada Ione', 'Aécio Neves',
#        'Gilson Daniel', 'Daniel Freitas', 'Eunício Oliveira',
#        'Joaquim Passarinho', 'José Medeiros', 'Kim Kataguiri',
#        'Pedro Lupion', 'Socorro Neri', 'Plínio Valério',
#        'Jaime Bagattoli', 'Carla Zambelli', 'André Fernandes',
#        'Denise Pessôa', 'Ivete da Silveira', 'Filipe Martins',
#        'Gabriel Mota', 'Túlio Gadêlha', 'Domingos Sávio',
#        'Pedro Lucas Fernandes', 'Mauro Benevides Filho', 'Sérgio Petecão',
#        'Cabo Gilberto Silva', 'Clodoaldo Magalhães', 'Wilson Santiago',
#        'Otto Alencar', 'Capitão Alden', 'Vicentinho', 'Hugo Motta',
#        'Gervásio Maia', 'Ricardo Barros', 'Soraya Thronicke',
#        'Dr. Francisco', 'Rubens Otoni', 'Renata Abreu', 'Esperidião Amin',
#        'Dilvanda Faro', 'Bandeira de Mello', 'Benes Leocádio',
#        'Prof. Reginaldo Veras', 'Professora Dorinha Seabra',
#        'Márcio Correa', 'Marcelo Álvaro Antônio', 'Pastor Diniz',
#        'Nelsinho Trad', 'Márcio Marinho', 'Clarissa Tércio',
#        'Renildo Calheiros', 'Natália Bonavides', 'Ana Paula Leão',
#        'Gilson Marques', 'Fernando Rodolfo', 'Zé Haroldo Cathedral',
#        'Marcos Pollon', 'Patrus Ananias', 'Fabio Schiochet',
#        'Paulo Alexandre Barbosa', 'Afonso Motta', 'Idilvan Alencar',
#        'Sérgio Brito', 'Paulo Folletto', 'Rogério Correia',
#        'Reginaldo Lopes', 'Lafayette de Andrada', 'Rodrigo Pacheco',
#        'Sanderson', 'Afonso Hamm', 'Paulão', 'Luciano Ducci',
#        'Greyce Elias', 'Roberto Duarte', 'Saulo Pedroso', 'Tião Medeiros',
#        'Pedro Aihara', 'Sargento Gonçalves', 'Magda Mofatto',
#        'Silvye Alves', 'Cleitinho', 'Delegado Ramagem',
#        'Coronel Fernanda', 'Dra. Alessandra Haber', 'Augusto Coutinho',
#        'Rodrigo de Castro', 'Raimundo Costa', 'Padre João',
#        'Maria do Rosário', 'Wilder Morais', 'Zequinha Marinho',
#        'Fernando Mineiro', 'Leo Prates', 'Delegado Matheus Laiola',
#        'Nikolas Ferreira', 'Paulo Abi-Ackel', 'Cobalchini',
#        'Confúcio Moura', 'Luiz Couto', 'Carlos Sampaio', 'Chris Tonietto',
#        'Osmar Terra', 'Luiz Carlos Busato', 'Carlos Jordy',
#        'Fernando Farias', 'Giordano', 'Delegado Caveira',
#        'Wellington Roberto', 'Julio Lopes', 'Odair Cunha',
#        'Dep. Roseana Sarney', 'Átila Lins', 'Luiz Carlos Hauly',
#        'Dagoberto Nogueira', 'Magno Malta', 'Márcio Jerry',
#        'Teresa Leitão', 'Fernando Coelho Filho', 'Paulinho da Força',
#        'Vinicius Gurgel', 'Vinicius Carvalho', 'Aguinaldo Ribeiro',
#        'Diego Andrade', 'Aureo Ribeiro', 'Sandro Alex',
#        'Paulo Freire Costa', 'Zeca Dirceu', 'Alceu Moreira',
#        'Giovani Cherini', 'Omar Aziz', 'Afonso Florence',
#        'Luisa Canziani', 'Stefano Aguiar', 'Davi Alcolumbre',
#        'Aluisio Mendes', 'Bacelar', 'Baleia Rossi', 'Daniela Reinehr',
#        'Covatti Filho', 'Diego Garcia', 'Dilceu Sperafico',
#        'Merlong Solano', 'Elcione Barbalho', 'Leandre', 'Marreca Filho',
#        'José Priante', 'João Leão', 'Alberto Mourão', 'Miguel Lombardi',
#        'Márcio Biolchi', 'Marcio Alvino', 'Nilto Tatto',
#        'Moses Rodrigues', 'Toninho Wandscheer', 'Vicentinho Júnior',
#        'Romário', 'Flávio Nogueira', 'Aj Albuquerque', 'Alex Santana',
#        'Beto Pereira', 'Caroline de Toni', 'Celso Sabino',
#        'Cezinha de Madureira', 'Dr. Luiz Ovando', 'David Soares',
#        'Daniela do Waguinho', 'Daniel Trzeciak', 'Coronel Chrisóstomo',
#        'Delegado Marcelo Freitas', 'Dr. Jaziel', 'Filipe Barros',
#        'Emanuel Pinheiro Neto', 'Gilberto Abramo',
#        'Hercílio Coelho Diniz', 'Gleisi Hoffmann', 'Isnaldo Bulhões Jr.',
#        'José Nelto', 'Júnior Ferrari', 'Luiz Carlos Motta',
#        'Marcelo Moraes', 'Marcos Aurélio Sampaio', 'Dr. Allan Garcês',
#        'Ricardo Guidi', 'Professor Alcides', 'Lucas Barreto',
#        'Marcio Bittar', 'Zenaide Maia', 'Mara Gabrilli', 'Helio Lopes',
#        'Rogério Carvalho', 'Silvia Cristina', 'Angelo Coronel',
#        'Chico Rodrigues', 'Carlos Fávaro', 'Joseildo Ramos',
#        'Luciano Vieira', 'Dr. Hiran', 'Rogério Marinho', 'Murillo Gouvea',
#        'Adilson Barroso', 'Alexandre Guimarães', 'Beto Preto',
#        'Amália Barros', 'Coronel Telhada', 'Eriberto Medeiros',
#        'Duda Salabert', 'Fábio Macedo', 'Dr. Victor Linhalis',
#        'Franciane Bayer', 'Guilherme Uchoa', 'Fernanda Pessoa',
#        'Fábio Teruel', 'Gilvan da Federal', 'Fred Linhares', 'Ismael',
#        'Jadyel Alencar', 'Ivoneide Caetano', 'Lêda Borges',
#        'Kiko Celeguim', 'Lucas Ramos', 'Marussa Boldrin',
#        'Mauricio Marcon', 'Miguel Ângelo', 'Mauricio Neves', 'Max Lemos',
#        'Mersinho Lucena', 'Nely Aquino', 'Neto Carletto', 'Pezenti',
#        'Rafael Simoes', 'Professora Goreth', 'Reginete Bispo',
#        'Robinson Faria', 'Sargento Portugal', 'Zé Trovão',
#        'Yury do Paredão', 'Vander Loubet', 'Marcos Rogério', 'Luiz Lima',
#        'Domingos Neto', 'Leonardo Monteiro', 'Daiana Santos',
#        'Ricardo Silva', 'Leila Barros', 'Dr. Daniel Soranz',
#        'Silas Câmara', 'Pedro Paulo', 'Eduardo Bolsonaro', 'Helena Lima',
#        'Juarez Costa', 'Acácio Favacho', 'Meire Serafim', 'Gilvan Maximo',
#        'Jorge Braz', 'Dal Barreto', 'Dep. Josivaldo JP', 'Marx Beltrão',
#        'Valmir Assunção', 'Alex Manente', 'Leur Lomanto Júnior',
#        'Ricardo Maia', 'Sonize Barbosa', 'Dr. Fernando Máximo',
#        'Alfredo Gaspar', 'Augusto Puppio', 'Rodolfo Nogueira',
#        'Rosana Valle', 'Roberta Roma', 'Jandira Feghali', 'Iza Arruda',
#        'Fabio Garcia', 'Laura Carneiro', 'Cid Gomes', 'Ely Santos',
#        'Camila Jara', 'Bruno Ganem', 'Dandara', 'Daniel Barbosa',
#        'Dayany Bittencourt', 'Gerlen Diniz', 'General Pazuello',
#        'Rosângela Moro', 'André Janones', 'Adail Filho',
#        'José Airton Félix Cirilo', 'Pastor Sargento Isidório',
#        'Soraya Santos', 'Nicoletti', 'Capitão Alberto Neto',
#        'Pr. Marco Feliciano', 'Bebeto', 'Silvia Waiãpi', 'Célia Xakriabá',
#        'Antônia Lúcia', 'Geraldo Resende', 'Marcos Soares',
#        'Orlando Silva', 'Fernanda Melchionna', 'Tabata Amaral',
#        'Albuquerque', 'Matheus Noronha', 'Saullo Vianna',
#        'Prof. Paulo Fernando', 'Andreia Siqueira', 'Rafael Prudente',
#        'Duda Ramos', 'Messias Donato', 'Roberto Monteiro Pai',
#        'Delegada Adriana Accorsi', 'Rosangela Gomes', 'Altineu Côrtes',
#        'Bia Kicis', 'Delegado da Cunha', 'Simone Marquetto',
#        'Daniella Ribeiro'], dtype=object)

# %%
df_deputados.nome.unique()
# Out:
# array(['Abilio Brunini', 'Acácio Favacho', 'Adail Filho',
#        'Adilson Barroso', 'Adolfo Viana', 'Adriana Ventura',
#        'Adriano do Baldy', 'Aécio Neves', 'Afonso Hamm', 'Afonso Motta',
#        'Aguinaldo Ribeiro', 'Airton Faleiro', 'AJ Albuquerque',
#        'Alberto Fraga', 'Alberto Mourão', 'Albuquerque', 'Alceu Moreira',
#        'Alencar Santana', 'Alex Manente', 'Alex Santana',
#        'Alexandre Guimarães', 'Alexandre Leite', 'Alexandre Lindenmeyer',
#        'Alfredinho', 'Alfredo Gaspar', 'Alice Portugal', 'Aliel Machado',
#        'Allan Garcês', 'Altineu Côrtes', 'Aluisio Mendes',
#        'Amanda Gentil', 'Amaro Neto', 'Amom Mandel', 'Ana Paula Leão',
#        'Ana Paula Lima', 'Ana Pimentel', 'André Ferreira',
#        'André Figueiredo', 'André Janones', 'Andreia Siqueira',
#        'Antônia Lúcia', 'Antonio Andrade', 'Antonio Brito',
#        'Antonio Carlos Rodrigues', 'Antônio Doido', 'Any Ortiz',
#        'Arlindo Chinaglia', 'Arnaldo Jardim', 'Arthur Lira',
#        'Arthur Oliveira Maia', 'Átila Lins', 'Átila Lira',
#        'Augusto Coutinho', 'Augusto Puppio', 'Aureo Ribeiro', 'Bacelar',
#        'Baleia Rossi', 'Bandeira de Mello', 'Bebeto', 'Benedita da Silva',
#        'Benes Leocádio', 'Beto Pereira', 'Beto Richa', 'Bia Kicis',
#        'Bibo Nunes', 'Bohn Gass', 'Bruno Farias', 'Bruno Ganem',
#        'Cabo Gilberto Silva', 'Camila Jara', 'Capitão Alberto Neto',
#        'Capitão Alden', 'Capitão Augusto', 'Carla Zambelli',
#        'Carlos Chiodini', 'Carlos Henrique Gaguim', 'Carlos Jordy',
#        'Carlos Sampaio', 'Carlos Veras', 'Carlos Zarattini',
#        'Carmen Zanotto', 'Carol Dartora', 'Caroline de Toni',
#        'Castro Neto', 'Célia Xakriabá', 'Célio Silveira', 'Célio Studart',
#        'Celso Russomanno', 'Cezinha de Madureira', 'Charles Fernandes',
#        'Chico Alencar', 'Chiquinho Brazão', 'Chris Tonietto',
#        'Clarissa Tércio', 'Claudio Cajado', 'Cleber Verde',
#        'Clodoaldo Magalhães', 'Cobalchini', 'Coronel Assis',
#        'Coronel Chrisóstomo', 'Coronel Fernanda', 'Coronel Meira',
#        'Coronel Ulysses', 'Covatti Filho', 'Cristiane Lopes',
#        'Da Vitoria', 'Dagoberto Nogueira', 'Daiana Santos', 'Dal Barreto',
#        'Damião Feliciano', 'Dandara', 'Dani Cunha', 'Daniel Agrobom',
#        'Daniel Almeida', 'Daniel Barbosa', 'Daniel Freitas',
#        'Daniel Trzeciak', 'Daniela do Waguinho', 'Daniela Reinehr',
#        'Danilo Forte', 'Danrlei de Deus Hinterholz', 'David Soares',
#        'Dayany Bittencourt', 'Defensor Stélio Dener',
#        'Delegada Adriana Accorsi', 'Delegada Ione', 'Delegada Katarina',
#        'Delegado Bruno Lima', 'Delegado Caveira', 'Delegado da Cunha',
#        'Delegado Éder Mauro', 'Delegado Fabio Costa',
#        'Delegado Marcelo Freitas', 'Delegado Matheus Laiola',
#        'Delegado Palumbo', 'Delegado Paulo Bilynskyj', 'Delegado Ramagem',
#        'Denise Pessôa', 'Detinha', 'Diego Andrade', 'Diego Coronel',
#        'Diego Garcia', 'Dilceu Sperafico', 'Dilvanda Faro',
#        'Dimas Fabiano', 'Dimas Gadelha', 'Domingos Neto',
#        'Domingos Sávio', 'Dorinaldo Malafaia', 'Douglas Viegas',
#        'Doutor Luizinho', 'Dr. Benjamim', 'Dr. Fernando Máximo',
#        'Dr. Francisco', 'Dr. Frederico', 'Dr. Jaziel', 'Dr. Luiz Ovando',
#        'Dr. Victor Linhalis', 'Dr. Zacharias Calil',
#        'Dra. Alessandra Haber', 'Dra. Mayra Pinheiro', 'Duarte Jr.',
#        'Duda Ramos', 'Duda Salabert', 'Eduardo Bismarck',
#        'Eduardo Bolsonaro', 'Eduardo da Fonte', 'Eduardo Velloso',
#        'Elcione Barbalho', 'Eli Borges', 'Elmar Nascimento', 'Ely Santos',
#        'Emanuel Pinheiro Neto', 'Emidinho Madeira', 'Eriberto Medeiros',
#        'Erika Hilton', 'Erika Kokay', 'Eros Biondini',
#        'Euclydes Pettersen', 'Eunício Oliveira', 'Evair Vieira de Melo',
#        'Fábio Macedo', 'Fabio Reis', 'Fabio Schiochet', 'Fábio Teruel',
#        'Fausto Pinato', 'Fausto Santos Jr.', 'Felipe Carreras',
#        'Felipe Francischini', 'Félix Mendonça Júnior',
#        'Fernanda Melchionna', 'Fernanda Pessoa', 'Fernando Coelho Filho',
#        'Fernando Mineiro', 'Fernando Monteiro', 'Fernando Rodolfo',
#        'Filipe Barros', 'Filipe Martins', 'Flávia Morais',
#        'Flávio Nogueira', 'Florentino Neto', 'Franciane Bayer',
#        'Fred Costa', 'Fred Linhares', 'Gabriel Mota', 'Gabriel Nunes',
#        'General Girão', 'General Pazuello', 'Geraldo Resende',
#        'Gerlen Diniz', 'Gervásio Maia', 'Giacobo', 'Gilberto Abramo',
#        'Gilberto Nascimento', 'Gilson Daniel', 'Gilson Marques',
#        'Gilvan da Federal', 'Gilvan Maximo', 'Giovani Cherini',
#        'Gisela Simona', 'Glauber Braga', 'Glaustin da Fokus',
#        'Gleisi Hoffmann', 'Greyce Elias', 'Guilherme Boulos',
#        'Guilherme Uchoa', 'Gustavo Gayer', 'Gustinho Ribeiro',
#        'Gutemberg Reis', 'Heitor Schuch', 'Helder Salomão', 'Helena Lima',
#        'Hélio Leite', 'Helio Lopes', 'Henderson Pinto',
#        'Hercílio Coelho Diniz', 'Hugo Leal', 'Hugo Motta',
#        'Icaro de Valmir', 'Idilvan Alencar', 'Igor Timo', 'Ismael',
#        'Ismael Alexandrino', 'Isnaldo Bulhões Jr.', 'Ivan Valente',
#        'Ivoneide Caetano', 'Iza Arruda', 'Jack Rocha', 'Jadyel Alencar',
#        'Jandira Feghali', 'Jeferson Rodrigues', 'Jefferson Campos',
#        'Jilmar Tatto', 'João Carlos Bacelar', 'João Daniel', 'João Leão',
#        'João Maia', 'Joaquim Passarinho', 'Jonas Donizette', 'Jorge Braz',
#        'Jorge Goetten', 'Jorge Solla', 'José Airton Félix Cirilo',
#        'José Guimarães', 'José Medeiros', 'José Nelto', 'José Priante',
#        'José Rocha', 'Joseildo Ramos', 'Josenildo', 'Josias Gomes',
#        'Josimar Maranhãozinho', 'Josivaldo JP', 'Juarez Costa',
#        'Julia Zanatta', 'Juliana Cardoso', 'Julio Arcoverde',
#        'Júlio Cesar', 'Julio Cesar Ribeiro', 'Julio Lopes',
#        'Juninho do Pneu', 'Junio Amaral', 'Júnior Ferrari',
#        'Junior Lourenço', 'Keniston Braga', 'Kiko Celeguim',
#        'Kim Kataguiri', 'Lafayette de Andrada', 'Laura Carneiro',
#        'Lázaro Botelho', 'Lebrão', 'Lêda Borges', 'Leo Prates',
#        'Leonardo Monteiro', 'Leur Lomanto Júnior', 'Lídice da Mata',
#        'Lincoln Portela', 'Lindbergh Farias', 'Lucas Ramos',
#        'Lucas Redecker', 'Luciano Alves', 'Luciano Amaral',
#        'Luciano Bivar', 'Luciano Ducci', 'Luciano Vieira',
#        'Lucio Mosquini', 'Luis Carlos Gomes', 'Luis Tibé',
#        'Luisa Canziani', 'Luiz Carlos Busato', 'Luiz Carlos Hauly',
#        'Luiz Carlos Motta', 'Luiz Couto', 'Luiz Fernando Faria',
#        'Luiz Gastão', 'Luiz Lima', 'Luiz Nishimori',
#        'Luiz Philippe de Orleans e Bragança', 'Luiza Erundina',
#        'Luizianne Lins', 'Lula da Fonte', 'Magda Mofatto', 'Marangoni',
#        'Marcel van Hattem', 'Marcelo Álvaro Antônio', 'Marcelo Crivella',
#        'Marcelo Moraes', 'Marcelo Queiroz', 'Marcio Alvino',
#        'Márcio Biolchi', 'Márcio Honaiser', 'Márcio Jerry',
#        'Márcio Marinho', 'Marco Brasil', 'Marcon',
#        'Marcos Aurélio Sampaio', 'Marcos Pereira', 'Marcos Pollon',
#        'Marcos Soares', 'Marcos Tavares', 'Maria Arraes',
#        'Maria do Rosário', 'Maria Rosas', 'Mario Frias', 'Mário Heringer',
#        'Mário Negromonte Jr.', 'Marreca Filho', 'Marussa Boldrin',
#        'Marx Beltrão', 'Matheus Noronha', 'Maurício Carvalho',
#        'Mauricio do Vôlei', 'Mauricio Marcon', 'Mauricio Neves',
#        'Mauro Benevides Filho', 'Max Lemos', 'Meire Serafim',
#        'Mendonça Filho', 'Merlong Solano', 'Mersinho Lucena',
#        'Messias Donato', 'Miguel Ângelo', 'Miguel Lombardi',
#        'Misael Varella', 'Moses Rodrigues', 'Murillo Gouvea',
#        'Murilo Galdino', 'Natália Bonavides', 'Nelson Barbudo',
#        'Nely Aquino', 'Neto Carletto', 'Newton Bonin',
#        'Newton Cardoso Jr', 'Nicoletti', 'Nikolas Ferreira',
#        'Nilto Tatto', 'Odair Cunha', 'Olival Marques', 'Orlando Silva',
#        'Osmar Terra', 'Ossesio Silva', 'Otoni de Paula',
#        'Otto Alencar Filho', 'Padovani', 'Padre João', 'Pastor Diniz',
#        'Pastor Eurico', 'Pastor Gil', 'Pastor Henrique Vieira',
#        'Pastor Sargento Isidório', 'Patrus Ananias', 'Paulão',
#        'Paulinho da Força', 'Paulinho Freire', 'Paulo Abi-Ackel',
#        'Paulo Alexandre Barbosa', 'Paulo Azi', 'Paulo Folletto',
#        'Paulo Freire Costa', 'Paulo Guedes', 'Paulo Litro',
#        'Paulo Magalhães', 'Pedro Aihara', 'Pedro Campos',
#        'Pedro Lucas Fernandes', 'Pedro Lupion', 'Pedro Paulo',
#        'Pedro Uczai', 'Pedro Westphalen', 'Pezenti', 'Pinheirinho',
#        'Pompeo de Mattos', 'Pr. Marco Feliciano', 'Prof. Reginaldo Veras',
#        'Professor Alcides', 'Professora Goreth',
#        'Professora Luciene Cavalcante', 'Rafael Brito', 'Rafael Prudente',
#        'Rafael Simoes', 'Raimundo Costa', 'Raimundo Santos',
#        'Reginaldo Lopes', 'Reginete Bispo', 'Reimont',
#        'Reinhold Stephanes', 'Renan Ferreirinha', 'Renata Abreu',
#        'Renilce Nicodemos', 'Renildo Calheiros', 'Ricardo Ayres',
#        'Ricardo Guidi', 'Ricardo Maia', 'Ricardo Salles', 'Ricardo Silva',
#        'Robério Monteiro', 'Roberta Roma', 'Roberto Duarte',
#        'Roberto Monteiro Pai', 'Robinson Faria', 'Rodolfo Nogueira',
#        'Rodrigo de Castro', 'Rodrigo Estacho', 'Rodrigo Gambale',
#        'Rodrigo Valadares', 'Rogéria Santos', 'Rogério Correia',
#        'Romero Rodrigues', 'Ronaldo Nogueira', 'Rosana Valle',
#        'Rosangela Moro', 'Rosângela Reis', 'Roseana Sarney',
#        'Rubens Otoni', 'Rubens Pereira Júnior', 'Rui Falcão',
#        'Ruy Carneiro', 'Sâmia Bomfim', 'Samuel Viana', 'Sanderson',
#        'Sargento Fahur', 'Sargento Gonçalves', 'Sargento Portugal',
#        'Saullo Vianna', 'Saulo Pedroso', 'Sergio Souza', 'Sidney Leite',
#        'Silas Câmara', 'Silvia Cristina', 'Silvia Waiãpi', 'Silvye Alves',
#        'Simone Marquetto', 'Socorro Neri', 'Sonize Barbosa',
#        'Soraya Santos', 'Sóstenes Cavalcante', 'Stefano Aguiar',
#        'Tabata Amaral', 'Tadeu Oliveira', 'Tadeu Veneri',
#        'Talíria Petrone', 'Tarcísio Motta', 'Thiago de Joaldo',
#        'Thiago Flores', 'Tião Medeiros', 'Tiririca', 'Toninho Wandscheer',
#        'Túlio Gadêlha', 'Valmir Assunção', 'Vander Loubet', 'Vermelho',
#        'Vicentinho', 'Vicentinho Júnior', 'Vinicius Carvalho',
#        'Vinicius Gurgel', 'Vitor Lippi', 'Waldemar Oliveira',
#        'Waldenor Pereira', 'Washington Quaquá', 'Weliton Prado',
#        'Wellington Roberto', 'Welter', 'Wilson Santiago', 'Yandra Moura',
#        'Yury do Paredão', 'Zé Haroldo Cathedral', 'Zé Neto', 'Zé Silva',
#        'Zé Trovão', 'Zé Vitor', 'Zeca Dirceu', 'Zezinho Barbary', 'Zucco'],
#       dtype=object)

# %%
len(set(df.nome_parlamentar_emenda_plano_acao.unique())-set(df_deputados.nome.unique()))
# Out:
# 94

# %%
len(df_deputados.nome.unique())
# Out:
# 513

# %%
#df[df['nome_parlamentar_emenda_plano_acao']=='Astronauta Marcos Pontes']
df_deputados[df_deputados['nome'].str.contains('Fernandes')]
# Out:
#          id                                                uri  \
# 89   205476  https://dadosabertos.camara.leg.br/api/v2/depu...
# 404  122974  https://dadosabertos.camara.leg.br/api/v2/depu...
#
#                       nome partido  \
# 89       Charles Fernandes     PSD
# 404  Pedro Lucas Fernandes   UNIÃO
#
#                                             uriPartido siglaUf  idLegislatura  \
# 89   https://dadosabertos.camara.leg.br/api/v2/part...      BA             57
# 404  https://dadosabertos.camara.leg.br/api/v2/part...      MA             57
#
#                                                urlFoto  \
# 89   https://www.camara.leg.br/internet/deputado/ba...
# 404  https://www.camara.leg.br/internet/deputado/ba...
#
#                                      email
# 89      dep.charlesfernandes@camara.leg.br
# 404  dep.pedrolucasfernandes@camara.leg.br

# %%
import requests
import pandas as pd

# URL da API para buscar senadores
url = "https://legis.senado.leg.br/dadosabertos/senador/lista/atual.json"

# Fazer a requisição à API
response = requests.get(url)

# Verificar se a resposta foi bem-sucedida
if response.status_code == 200:
    # Parse do JSON
    data = response.json()

    # Extrair os dados relevantes
    senadores = data['ListaParlamentarEmExercicio']['Parlamentares']['Parlamentar']
    nomes = []
    partidos = []
    ufs = []

    for senador in senadores:
        nome = senador['IdentificacaoParlamentar']['NomeParlamentar']
        partido = senador['IdentificacaoParlamentar']['SiglaPartidoParlamentar']
        uf =  senador['IdentificacaoParlamentar']['UfParlamentar']
        nomes.append(nome)
        partidos.append(partido)
        ufs.append(uf)

    # Criar um DataFrame para exibir os dados
    #df = pd.DataFrame({'Nome': nomes, 'Partido': partidos})
    df_senadores = pd.DataFrame({'nome': nomes, 'partido': partidos, 'uf': ufs})
    print(df_senadores)
else:
    print(f"Erro ao acessar a API. Código de status: {response.status_code}")
# Out:
#                         nome  partido  uf
# 0                  Alan Rick    UNIÃO  AC
# 1          Alessandro Vieira      MDB  SE
# 2           Ana Paula Lobato      PDT  MA
# 3             Angelo Coronel      PSD  BA
# 4   Astronauta Marcos Pontes       PL  SP
# ..                       ...      ...  ..
# 76       Wellington Fagundes       PL  MT
# 77                  Weverton      PDT  MA
# 78             Wilder Morais       PL  GO
# 79              Zenaide Maia      PSD  RN
# 80          Zequinha Marinho  PODEMOS  PA
#
# [81 rows x 3 columns]

# %%
set(df.nome_parlamentar_emenda_plano_acao.unique())-set(df_deputados.nome.unique())-set(df_senadores.nome.unique())
# Out:
# {'Afonso Florence',
#  'Aj Albuquerque',
#  'Amália Barros',
#  'André Fernandes',
#  'Beto Preto',
#  'Carlos Fávaro',
#  'Carlos Gomes',
#  'Celso Sabino',
#  'Coronel Telhada',
#  'Dep. Josivaldo JP',
#  'Dep. Roseana Sarney',
#  'Dr. Allan Garcês',
#  'Dr. Daniel Soranz',
#  'Evair Vieira De Melo',
#  'Fabio Garcia',
#  'Geraldo Mendes',
#  'Ivete da Silveira',
#  'Júnior Mano',
#  'Leandre',
#  'Márcio Correa',
#  'Paulo Marinho JR',
#  'Prof. Paulo Fernando',
#  'Ricardo Barros',
#  'Rogério Marinho',
#  'Rosangela Gomes',
#  'Rosângela Moro',
#  'Sandro Alex',
#  'Silvio Antonio',
#  'Sérgio Brito'}

# %%
df_deputados.columns
# Out:
# Index(['id', 'uri', 'nome', 'partido', 'uriPartido', 'siglaUf',
#        'idLegislatura', 'urlFoto', 'email'],
#       dtype='object')

# %%
# Supondo que 'nome_parlamentar_emenda_plano_acao' seja a chave de união

# Merge com df_deputados
df_emendas = df.merge(
    df_deputados.rename(columns={'nome': 'nome_parlamentar_emenda_plano_acao'}),
    on='nome_parlamentar_emenda_plano_acao',
    how='left',
    suffixes=('', '_deputado')
)
df_emendas['cargo']=None
df_emendas.loc[df_emendas['partido'].notna(),['cargo']]='deputado'
print(df_emendas.columns)

# Merge com df_senadores
df_emendas = df_emendas.merge(
    df_senadores.rename(columns={'nome': 'nome_parlamentar_emenda_plano_acao'}),
    on='nome_parlamentar_emenda_plano_acao',
    how='left',
    suffixes=('', '_senador')
)
#
df_emendas.loc[df_emendas['partido_senador'].notna(),['cargo']]='senador'

# Verifica se as colunas existem antes de usar fillna
if 'partido_senador' in df_emendas.columns:
    df_emendas['partido'] = df_emendas['partido'].fillna(df_emendas['partido_senador'])
if 'uf_senador' in df_emendas.columns:
    df_emendas['uf'] = df_emendas['uf'].fillna(df_emendas['uf_senador'])

# Remover colunas extras se existirem
df_emendas = df_emendas.drop(
    columns=[col for col in ['partido_senador', 'uf_senador', 'partido_deputado', 'uf_deputado'] if col in df_emendas.columns]
)

# Resultado final
df_emendas
# Out:
# Index(['id_plano_acao', 'codigo_plano_acao', 'ano_plano_acao',
#        'modalidade_plano_acao', 'situacao_plano_acao',
#        'cnpj_beneficiario_plano_acao', 'nome_beneficiario_plano_acao',
#        'uf_beneficiario_plano_acao', 'codigo_banco_plano_acao',
#        'codigo_situacao_dado_bancario_plano_acao', 'nome_banco_plano_acao',
#        'numero_agencia_plano_acao', 'dv_agencia_plano_acao',
#        'numero_conta_plano_acao', 'dv_conta_plano_acao',
#        'nome_parlamentar_emenda_plano_acao',
#        'ano_emenda_parlamentar_plano_acao',
#        'codigo_parlamentar_emenda_plano_acao',
#        'sequencial_emenda_parlamentar_plano_acao',
#        'numero_emenda_parlamentar_plano_acao',
#        'codigo_emenda_parlamentar_formatado_plano_acao',
#        'codigo_descricao_areas_politicas_publicas_plano_acao',
#        'descricao_programacao_orcamentaria_plano_acao',
#        'motivo_impedimento_plano_acao', 'valor_custeio_plano_acao',
#        'valor_investimento_plano_acao', 'id_programa', 'valor_emenda', 'id',
#        'uri', 'partido', 'uriPartido', 'siglaUf', 'idLegislatura', 'urlFoto',
#        'email', 'cargo'],
#       dtype='object')
#        id_plano_acao codigo_plano_acao  ano_plano_acao modalidade_plano_acao  \
# 0              69182   09032024-069182            2024              Especial
# 1              64478   09032024-064478            2024              Especial
# 2              64487   09032024-064487            2024              Especial
# 3              72493   09032024-072493            2024              Especial
# 4              73453   09032024-073453            2024              Especial
# ...              ...               ...             ...                   ...
# 10929          74317   09032024-074317            2024              Especial
# 10930          69119   09032024-069119            2024              Especial
# 10931          73476   09032024-073476            2024              Especial
# 10932          72488   09032024-072488            2024              Especial
# 10933          69007   09032024-069007            2024              Especial
#
#       situacao_plano_acao cnpj_beneficiario_plano_acao  \
# 0                  CIENTE               95990131000170
# 1                  CIENTE               41522186000126
# 2                  CIENTE               01612590000176
# 3                  CIENTE               18114264000131
# 4                  CIENTE               18114264000131
# ...                   ...                          ...
# 10929              CIENTE               75368928000122
# 10930              CIENTE               14196042000154
# 10931              CIENTE               18094870000132
# 10932              CIENTE               46362927000172
# 10933              CIENTE               02295772000123
#
#                 nome_beneficiario_plano_acao uf_beneficiario_plano_acao  \
# 0                MUNICIPIO DE NOVA ITABERABA                         SC
# 1      MUNICIPIO DE PASSAGEM FRANCA DO PIAUI                         PI
# 2                MUNICIPIO DE MILTON BRANDAO                         PI
# 3                  MUNICIPIO DE ESPERA FELIZ                         MG
# 4                  MUNICIPIO DE ESPERA FELIZ                         MG
# ...                                      ...                        ...
# 10929                   MUNICIPIO DE MAMBORE                         PR
# 10930                              TEOLÂNDIA                         BA
# 10931      MUNICIPIO DE SENHORA DOS REMEDIOS                         MG
# 10932                    MUNICIPIO DE BROTAS                         SP
# 10933                     MUNICIPIO DE GOIAS                         GO
#
#       codigo_banco_plano_acao  codigo_situacao_dado_bancario_plano_acao  ...  \
# 0                         104                                       4.0  ...
# 1                         001                                       4.0  ...
# 2                         104                                       4.0  ...
# 3                         104                                       4.0  ...
# 4                         104                                       4.0  ...
# ...                       ...                                       ...  ...
# 10929                     104                                       4.0  ...
# 10930                     104                                       4.0  ...
# 10931                     001                                       4.0  ...
# 10932                     104                                       4.0  ...
# 10933                     104                                       4.0  ...
#
#              id                                                uri  \
# 0      160604.0  https://dadosabertos.camara.leg.br/api/v2/depu...
# 1           NaN                                                NaN
# 2           NaN                                                NaN
# 3      178895.0  https://dadosabertos.camara.leg.br/api/v2/depu...
# 4      204524.0  https://dadosabertos.camara.leg.br/api/v2/depu...
# ...         ...                                                ...
# 10929       NaN                                                NaN
# 10930  204571.0  https://dadosabertos.camara.leg.br/api/v2/depu...
# 10931  204524.0  https://dadosabertos.camara.leg.br/api/v2/depu...
# 10932  178985.0  https://dadosabertos.camara.leg.br/api/v2/depu...
# 10933   74371.0  https://dadosabertos.camara.leg.br/api/v2/depu...
#
#             partido                                         uriPartido  \
# 0                PT  https://dadosabertos.camara.leg.br/api/v2/part...
# 1               PSD                                                NaN
# 2               PSD                                                NaN
# 3               PSD  https://dadosabertos.camara.leg.br/api/v2/part...
# 4                PP  https://dadosabertos.camara.leg.br/api/v2/part...
# ...             ...                                                ...
# 10929           NaN                                                NaN
# 10930  REPUBLICANOS  https://dadosabertos.camara.leg.br/api/v2/part...
# 10931            PP  https://dadosabertos.camara.leg.br/api/v2/part...
# 10932            PL  https://dadosabertos.camara.leg.br/api/v2/part...
# 10933            PT  https://dadosabertos.camara.leg.br/api/v2/part...
#
#       siglaUf idLegislatura  \
# 0          SC          57.0
# 1         NaN           NaN
# 2         NaN           NaN
# 3          MG          57.0
# 4          MG          57.0
# ...       ...           ...
# 10929     NaN           NaN
# 10930      BA          57.0
# 10931      MG          57.0
# 10932      SP          57.0
# 10933      GO          57.0
#
#                                                  urlFoto  \
# 0      https://www.camara.leg.br/internet/deputado/ba...
# 1                                                    NaN
# 2                                                    NaN
# 3      https://www.camara.leg.br/internet/deputado/ba...
# 4      https://www.camara.leg.br/internet/deputado/ba...
# ...                                                  ...
# 10929                                                NaN
# 10930  https://www.camara.leg.br/internet/deputado/ba...
# 10931  https://www.camara.leg.br/internet/deputado/ba...
# 10932  https://www.camara.leg.br/internet/deputado/ba...
# 10933  https://www.camara.leg.br/internet/deputado/ba...
#
#                                   email     cargo   uf
# 0          dep.pedrouczai@camara.leg.br  deputado  NaN
# 1                                   NaN   senador   PI
# 2                                   NaN   senador   PI
# 3       dep.misaelvarella@camara.leg.br  deputado  NaN
# 4         dep.pinheirinho@camara.leg.br  deputado  NaN
# ...                                 ...       ...  ...
# 10929                               NaN      None  NaN
# 10930     dep.alexsantana@camara.leg.br  deputado  NaN
# 10931     dep.pinheirinho@camara.leg.br  deputado  NaN
# 10932  dep.miguellombardi@camara.leg.br  deputado  NaN
# 10933     dep.rubensotoni@camara.leg.br  deputado  NaN
#
# [10934 rows x 38 columns]

# %%
# Resultado final
df_emendas.cargo.value_counts()
# Out:
# cargo
# deputado    8307
# senador     1894
# Name: count, dtype: int64

# %%
df_emendas.partido
# Out:
# 0                  PT
# 1                 PSD
# 2                 PSD
# 3                 PSD
# 4                  PP
#              ...
# 10929             NaN
# 10930    REPUBLICANOS
# 10931              PP
# 10932              PL
# 10933              PT
# Name: partido, Length: 10934, dtype: object

# %%
colunas = ['nome_parlamentar_emenda_plano_acao','partido']

# %%
print(df_emendas[colunas].isnull().sum())
# Out:
# nome_parlamentar_emenda_plano_acao      0
# partido                               733
# dtype: int64

# %%
df_emendas_deputados = (
    df_emendas[df_emendas['cargo']=='deputado']
    .groupby(colunas)
    .sum()
    ['valor_emenda']
    .sort_values(ascending=False)
    .head(10)
)
df_emendas_deputados
# Out:
# nome_parlamentar_emenda_plano_acao  partido
# Pastor Sargento Isidório            AVANTE           18935792.0
# Duda Ramos                          MDB              18935792.0
# Flávio Nogueira                     PT               18935792.0
# Paulinho da Força                   SOLIDARIEDADE    18935792.0
# Filipe Barros                       PL               18935792.0
# Pezenti                             MDB              18935792.0
# Pinheirinho                         PP               18935792.0
# Meire Serafim                       UNIÃO            18935792.0
# Fabio Schiochet                     UNIÃO            18935792.0
# Roberto Duarte                      REPUBLICANOS     18935792.0
# Name: valor_emenda, dtype: float64

# %%
df_emendas_senadores = (
    df_emendas[df_emendas['cargo']=='senador']
    .groupby(colunas)
    .sum()
    ['valor_emenda']
    .sort_values(ascending=False)
    .head(10)
)
df_emendas_senadores
# Out:
# nome_parlamentar_emenda_plano_acao  partido
# Jayme Campos                        UNIÃO      34817425.0
# Marcos Rogério                      PL         34817425.0
# Jussara Lima                        PSD        34817425.0
# Davi Alcolumbre                     UNIÃO      34815000.0
# Ciro Nogueira                       PP         34634850.0
# Otto Alencar                        PSD        34634850.0
# Giordano                            MDB        34500000.0
# Fernando Farias                     MDB        34317425.0
# Eliziane Gama                       PSD        34317425.0
# Angelo Coronel                      PSD        34134850.0
# Name: valor_emenda, dtype: float64

# %%
# Criando o gráfico de barras horizontais
plt.figure(figsize=(10, 6))
# Converting the MultiIndex to string labels
y_labels = df_emendas_senadores.index.map(lambda x: f'{x[0]} ({x[1]})')
plt.barh(y_labels,
         df_emendas_senadores.values,
         color='skyblue')

# Adicionando título e rótulos aos eixos
plt.title('Top 10 Senadores por Valor de Emendas', fontsize=16)
plt.xlabel('Valor Total das Emendas', fontsize=12)
plt.ylabel('Senadores', fontsize=12)

# Exibindo os valores nas barras
for index, value in enumerate(df_emendas_senadores.values):
    plt.text(value, index, f'{value:,.2f}', va='center', fontsize=10)

# Ajustando o layout
plt.tight_layout()

# Exibindo o gráfico
plt.show()

# %%
# Criando o gráfico de barras horizontais
plt.figure(figsize=(10, 6))
# Convert the MultiIndex to a list of strings
y_labels = [', '.join(map(str, item)) for item in df_emendas_deputados.index]
plt.barh(y_labels,
         df_emendas_deputados.values,
         color='skyblue')

# Adicionando título e rótulos aos eixos
plt.title('Top 10 Deputados por Valor de Emendas', fontsize=16)
plt.xlabel('Valor Total das Emendas', fontsize=12)
plt.ylabel('Deputados', fontsize=12)

# Exibindo os valores nas barras
# Note: Using len(y_labels) ensures we iterate through the correct number of bars
for index, value in enumerate(df_emendas_deputados.values):
    plt.text(value, index, f'{value:,.2f}', va='center', fontsize=10)

# Ajustando o layout
plt.tight_layout()

# Exibindo o gráfico
plt.show()
